# %%
# This script overwrites your index.md with a clean, professional version
index_content = """---
layout: default
title: Home
---

# Automated Technical Insights & AI
### Expert VMS Solutions | Strategic Business Growth

Helping partners master VMS platforms and drive long-term profitability through automated data insights and strategic system integration.

---

## Core Expertise
* **Automated Insights:** Streamlining technical data for better decision-making.
* **Strategic Growth:** Identifying cost-saving opportunities in your technical infrastructure.
* **VMS Mastery:** Expert-level management of complex VMS platforms.

[View our Services](/services) | [Contact Us](/contact)
"""

with open("index.md", "w") as f:
    f.write(index_content)
    print("✅ index.md has been cleaned and updated!")
# Out:
# ✅ index.md has been cleaned and updated!

# %%
import os

# Create the _data folder if it doesn't exist
if not os.path.exists('_data'):
    os.makedirs('_data')

nav_content = """
- name: Home
  link: /
- name: Services
  link: /services
- name: Portfolio
  link: /portfolio
- name: Contact
  link: /contact
"""

with open("_data/navigation.yml", "w") as f:
    f.write(nav_content)
    print("✅ Navigation menu created!")
# Out:
# ✅ Navigation menu created!

# %%
# 1. Update Config for the Cayman Theme
config_content = """
title: Orlando Velazquez
description: Technical Design | Automated Insights | Strategic Sales
remote_theme: pages-themes/cayman@v0.2.0
"""
# Added encoding="utf-8" here
with open("_config.yml", "w", encoding="utf-8") as f:
    f.write(config_content)

# 2. Comprehensive Services Page (With Emojis)
services_content = """---
layout: page
title: Professional Services
---

## 🏗️ Technical Design & Engineering
Leveraging my background in Electrical Engineering to provide high-end design solutions.
* **AutoCAD & Revit:** Professional drafting for mechanical and electrical systems.
* **Orthographic Projections:** Technical part drawings and viewport scaling.

## 🤖 Automated Technical Insights & AI
Custom Python-driven solutions to optimize business workflows.
* **VMS Mastery:** Expert platform integration and management.
* **Data Automation:** Custom scripts for financial analysis and system monitoring.

## 💳 Payment Solutions (Beacon Payments)
As an Independent Sales Representative (ISR), I help businesses reduce overhead and scale.
* **Payment Processing:** Secure, efficient merchant services.
* **Cost Reduction:** Strategic analysis of current payment infrastructures.
"""
# Added encoding="utf-8" here
with open("services.md", "w", encoding="utf-8") as f:
    f.write(services_content)

# 3. Contact Page with Calendly & LinkedIn
contact_content = """---
layout: page
title: Contact & Consultations
---

### Let's Connect
Whether you need a technical drawing, a custom automation script, or a payment processing audit, you can reach me directly below.

* **LinkedIn:** [Connect with me on LinkedIn](https://www.linkedin.com/in/orlando-velazquez-713bb33b7/)
* **Schedule a Meeting:** <link href="https://assets.calendly.com/assets/external/widget.css" rel="stylesheet">
<script src="https://assets.calendly.com/assets/external/widget.js" type="text/javascript" async></script>
<a href="" onclick="Calendly.initPopupWidget({url: 'https://calendly.com/YOUR_LINK_HERE'});return false;">Schedule time with me</a>

*Note: Replace 'YOUR_LINK_HERE' with your actual Calendly slug.*
"""
# Added encoding="utf-8" here
with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_content)

print("✅ Success! Files created with UTF-8 encoding.")
# Out:
# ✅ Success! Files created with UTF-8 encoding.

# %%
# Updated contact page with your specific Calendly link
calendly_link = "automated-technical-insights/new-meeting" 

contact_content = f"""---
layout: page
title: Contact & Consultations
---

### Let's Connect
Whether you need a technical drawing, a custom automation script, or a payment processing audit, you can reach me directly below.

* **LinkedIn:** [Connect with me on LinkedIn](https://www.linkedin.com/in/orlando-velazquez-713bb33b7/)
* **Schedule a Meeting:** <link href="https://assets.calendly.com/assets/external/widget.css" rel="stylesheet">
<script src="https://assets.calendly.com/assets/external/widget.js" type="text/javascript" async></script>
<a href="" onclick="Calendly.initPopupWidget({{url: 'https://calendly.com/{calendly_link}'}});return false;" style="background-color: #007bff; color: white; padding: 12px 24px; text-decoration: none; border-radius: 5px; display: inline-block; font-weight: bold;">Schedule time with me</a>

---
*Serving partners across technical design, VMS automation, and merchant services.*
"""

with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_content)

print("✅ Contact page finalized with your Calendly link!")
# Out:
# ✅ Contact page finalized with your Calendly link!

# %%
# 1. Update Config for the Umbrella Brand & Theme
config_content = """
title: ATI & AI
description: Automated Technical Insights & Artificial Intelligence
remote_theme: pages-themes/midnight@v0.2.0
"""
with open("_config.yml", "w", encoding="utf-8") as f:
    f.write(config_content)

# 2. Homepage: High-Level Corporate Vision
index_content = """---
layout: default
title: Home
---

# ATI & AI
### Advanced Infrastructure & Technical Intelligence

Strategic operational solutions for modern facilities and commerce. We bridge the gap between existing hardware and next-generation intelligence.

---

## Core Focus Areas

### 💳 Merchant POS Solutions
Strategic payment infrastructure management. We specialize in optimizing Point-of-Sale ecosystems to reduce overhead and streamline transaction flow through Beacon Payments.

### 🔌 VMS Integration & Maintenance
Comprehensive management of Video Management Systems. We ensure your existing security hardware remains reliable, optimized, and ready for future scaling.

### 👁️ Intelligence Layer (Coming Soon)
Our proprietary AI integration model. We are developing the capability to transform existing camera systems into proactive security networks, bringing advanced computer vision to legacy hardware.

---

[Explore Solutions](/services) | [Inquiry Portal](/contact)
"""

with open("index.md", "w", encoding="utf-8") as f:
    f.write(index_content)

# 3. Services: Purely Professional (No Background Info)
services_content = """---
layout: page
title: Solutions
---

## Technical Consultation
ATI & AI provides high-level oversight for businesses looking to modernize their technical infrastructure without overhauling their entire budget.

### Merchant Services
* POS System Audits
* Payment Processing Optimization (Beacon Payments)
* Transaction Security & Compliance

### Security Infrastructure
* VMS Integration & Maintenance
* Hardware Reliability Assessment
* **Next-Gen Security:** Ask about our upcoming AI-Model deployment for existing camera systems.
"""
with open("services.md", "w", encoding="utf-8") as f:
    f.write(services_content)

print("✅ ATI & AI Brand Redesign complete!")
# Out:
# ✅ ATI & AI Brand Redesign complete!

# %%
# Create/Update the CSS with unique styles for each page type
import os
if not os.path.exists('assets/css'):
    os.makedirs('assets/css')

custom_css = """
/* Global Branding */
body {
    background-color: #0b0e14;
    color: #cfd8dc;
    font-family: 'Inter', -apple-system, sans-serif;
}

header {
    background: linear-gradient(135deg, #0f172a 0%, #1e293b 100%);
    border-bottom: 3px solid #007bff;
    padding: 2rem 0;
}

/* Services Page Styling - Clean Grid Look */
.service-card {
    border-left: 4px solid #00d4ff;
    background: #161b22;
    padding: 20px;
    margin: 15px 0;
    border-radius: 0 8px 8px 0;
}

.merchant-accent { color: #2ecc71; border-color: #2ecc71; }
.vms-accent { color: #00d4ff; border-color: #00d4ff; }
.ai-accent { color: #a855f7; border-color: #a855f7; }

/* Contact Page Styling - Professional Portal */
.contact-container {
    background: #111827;
    border: 1px solid #374151;
    padding: 30px;
    border-radius: 12px;
    text-align: center;
}

.btn-contact {
    background: linear-gradient(90deg, #007bff, #00d4ff);
    color: white !important;
    font-weight: bold;
    padding: 15px 30px;
    border-radius: 50px;
    display: inline-block;
    transition: transform 0.2s;
}

.btn-contact:hover { transform: scale(1.05); }
"""

with open("assets/css/style.scss", "w", encoding="utf-8") as f:
    f.write("---\n---\n@import 'jekyll-theme-midnight';\n" + custom_css)

print("✅ Advanced UI Layer Applied!")
# Out:
# ✅ Advanced UI Layer Applied!

# %%
# Updating Services with the new Service Card look
services_content = """---
layout: page
title: Solutions Portfolio
---

<div class="service-card merchant-accent">
  <h2>💳 Merchant POS Solutions</h2>
  <p>Optimizing payment ecosystems through strategic hardware integration and transaction security audits.</p>
</div>

<div class="service-card vms-accent">
  <h2>🔌 VMS Infrastructure</h2>
  <p>Full-scale maintenance and synchronization of existing Video Management Systems to ensure 100% uptime.</p>
</div>

<div class="service-card ai-accent">
  <h2>👁️ Intelligence Layer</h2>
  <p><em>Phase 2 Development:</em> Implementing proprietary computer vision models into legacy camera hardware.</p>
</div>
"""

with open("services.md", "w", encoding="utf-8") as f:
    f.write(services_content)

# Updating Contact with the "Portal" look
contact_content = """---
layout: page
title: Inquiry Portal
---

<div class="contact-container">
  <h3>Secure Consultation Access</h3>
  <p>Request an audit for your current infrastructure or discuss POS optimization.</p>
  
  <br>
  
  <a href="https://calendly.com/automated-technical-insights/new-meeting" class="btn-contact">Open Calendly Portal</a>
  
  <br><br>
  
  <p><a href="https://www.linkedin.com/in/orlando-velazquez-713bb33b7/" style="color:#00d4ff;">Connect via LinkedIn</a></p>
</div>
"""

with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_content)

print("✅ Services and Contact pages updated with high-end CSS containers!")
# Out:
# ✅ Services and Contact pages updated with high-end CSS containers!

# %%
import os
if not os.path.exists('assets/css'): os.makedirs('assets/css')

corporate_css = """
/* Global Professional Theme */
:root {
    --bg-dark: #080a0f;
    --card-bg: #11141d;
    --accent-blue: #007bff;
    --accent-cyan: #00d4ff;
    --accent-purple: #a855f7;
    --text-main: #e2e8f0;
    --text-dim: #94a3b8;
}

body {
    background-color: var(--bg-dark);
    color: var(--text-main);
    font-family: 'Segoe UI', Roboto, Helvetica, Arial, sans-serif;
    line-height: 1.6;
}

/* High-End Header */
header {
    background: linear-gradient(135deg, #0f172a 0%, #1e293b 100%);
    border-bottom: 3px solid var(--accent-blue);
    padding: 3rem 0;
    text-shadow: 0 2px 4px rgba(0,0,0,0.5);
}

/* Glassmorphism Service Cards */
.solution-card {
    background: var(--card-bg);
    border: 1px solid #1e293b;
    border-radius: 12px;
    padding: 2.5rem;
    margin-bottom: 2rem;
    transition: all 0.3s ease;
    box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1);
}

.solution-card:hover {
    border-color: var(--accent-blue);
    transform: translateY(-5px);
    box-shadow: 0 20px 25px -5px rgba(0, 0, 0, 0.3);
}

.badge {
    display: inline-block;
    padding: 4px 12px;
    border-radius: 20px;
    font-size: 0.75rem;
    font-weight: bold;
    text-transform: uppercase;
    margin-bottom: 1rem;
}

.badge-vms { background: rgba(0, 212, 255, 0.1); color: var(--accent-cyan); border: 1px solid var(--accent-cyan); }
.badge-pos { background: rgba(46, 204, 113, 0.1); color: #2ecc71; border: 1px solid #2ecc71; }
.badge-ai { background: rgba(168, 85, 247, 0.1); color: var(--accent-purple); border: 1px solid var(--accent-purple); }

/* Corporate Inquiry Portal */
.inquiry-box {
    max-width: 600px;
    margin: 4rem auto;
    background: linear-gradient(180deg, #111827 0%, #080a0f 100%);
    border: 1px solid #334155;
    padding: 3rem;
    border-radius: 16px;
    text-align: center;
}

.btn-portal {
    background: linear-gradient(90deg, #007bff, #00d4ff);
    color: white !important;
    padding: 18px 40px;
    border-radius: 8px;
    text-decoration: none;
    font-weight: 700;
    letter-spacing: 1px;
    display: inline-block;
}
"""

with open("assets/css/style.scss", "w", encoding="utf-8") as f:
    f.write("---\n---\n@import 'jekyll-theme-midnight';\n" + corporate_css)

print("✅ Corporate CSS framework deployed.")
# Out:
# ✅ Corporate CSS framework deployed.

# %%
# Updated Services Page
services_content = """---
layout: page
title: Enterprise Solutions
---

<div class="solution-card">
  <span class="badge badge-pos">Operational Efficiency</span>
  <h2>Merchant POS Solutions</h2>
  <p>Strategic payment infrastructure for high-volume environments. We audit and optimize POS ecosystems to secure transaction flow and minimize processing friction through our partnership with <strong>Beacon Payments</strong>.</p>
</div>

<div class="solution-card">
  <span class="badge badge-vms">Infrastructure</span>
  <h2>VMS Integration & Maintenance</h2>
  <p>Ensuring 24/7 reliability for mission-critical Video Management Systems. We specialize in synchronizing legacy hardware with modern network protocols to prevent data loss and system downtime.</p>
</div>

<div class="solution-card">
  <span class="badge badge-ai">Phase 2 Development</span>
  <h2>Intelligence Layer Integration</h2>
  <p>Transforming passive monitoring into proactive security. Our upcoming AI deployment model allows facilities to implement advanced computer vision and behavioral analytics onto their existing camera networks.</p>
</div>
"""

with open("services.md", "w", encoding="utf-8") as f:
    f.write(services_content)

# Updated Contact Page
contact_content = """---
layout: page
title: Inquiry Portal
---

<div class="inquiry-box">
  <h2 style="color:#00d4ff;">Secure Consultation Access</h2>
  <p style="color:#94a3b8; font-size: 1.1rem;">ATI & AI provides strategic technical audits for facility security and merchant infrastructure.</p>
  
  <br><br>
  
  <a href="https://calendly.com/automated-technical-insights/new-meeting" class="btn-portal">INITIATE CONSULTATION</a>
  
  <br><br><br>
  
  <p><small style="color:#475569;">Encrypted External Channel:</small><br>
  <a href="https://www.linkedin.com/in/orlando-velazquez-713bb33b7/" style="color:#007bff; text-decoration:none;">LinkedIn Corporate Profile</a></p>
</div>
"""

with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_content)

print("✅ Solution cards and Portal layout deployed.")
# Out:
# ✅ Solution cards and Portal layout deployed.

# %%
import os
if not os.path.exists('assets/css'): os.makedirs('assets/css')

business_css = """
/* Global Reset & Corporate Color Palette */
:root {
    --bg-main: #0a0c10;
    --bg-card: #12151e;
    --accent: #007bff;
    --accent-glow: rgba(0, 123, 255, 0.4);
    --text-primary: #f8fafc;
    --text-secondary: #94a3b8;
    --border: #1e293b;
}

body {
    background-color: var(--bg-main);
    color: var(--text-primary);
    font-family: 'Segoe UI', system-ui, -apple-system, sans-serif;
    line-height: 1.7;
    margin: 0;
}

/* Modern Header with Depth */
header {
    background: linear-gradient(180deg, #0f172a 0%, var(--bg-main) 100%);
    border-bottom: 1px solid var(--border);
    padding: 60px 20px;
    text-align: center;
}

/* Solution Cards - The "Product" Feel */
.solution-container {
    max-width: 900px;
    margin: 0 auto;
    padding: 40px 20px;
}

.solution-card {
    background: var(--bg-card);
    border: 1px solid var(--border);
    border-radius: 16px;
    padding: 32px;
    margin-bottom: 24px;
    transition: all 0.4s cubic-bezier(0.175, 0.885, 0.32, 1.275);
    position: relative;
    overflow: hidden;
}

.solution-card:hover {
    border-color: var(--accent);
    box-shadow: 0 0 30px var(--accent-glow);
    transform: translateY(-8px);
}

.solution-card h2 {
    color: var(--accent);
    margin-top: 0;
    font-size: 1.5rem;
    letter-spacing: -0.5px;
}

/* Call to Action - Conversion Focus */
.cta-section {
    background: linear-gradient(90deg, #001e3c 0%, #000a14 100%);
    border: 1px solid var(--accent);
    border-radius: 20px;
    padding: 50px;
    text-align: center;
    margin-top: 60px;
}

.btn-primary {
    background: var(--accent);
    color: white !important;
    padding: 16px 36px;
    border-radius: 12px;
    text-decoration: none;
    font-weight: 700;
    font-size: 1.1rem;
    display: inline-block;
    box-shadow: 0 4px 14px 0 rgba(0, 123, 255, 0.39);
}
"""

with open("assets/css/style.scss", "w", encoding="utf-8") as f:
    f.write("---\n---\n@import 'jekyll-theme-midnight';\n" + business_css)

print("✅ Corporate CSS Framework Active.")
# Out:
# ✅ Corporate CSS Framework Active.

# %%
# Overwriting index.md (Homepage)
homepage = """---
layout: default
title: ATI & AI | Advanced Infrastructure
---

<header>
    <h1 style="font-size: 3rem; margin-bottom: 10px;">ATI & AI</h1>
    <p style="color: #94a3b8; font-size: 1.2rem;">Automated Technical Insights & Artificial Intelligence</p>
</header>

<div class="solution-container">
    <div class="solution-card">
        <h2>Merchant POS Optimization</h2>
        <p>Strategic merchant services auditing and POS system integration. We partner with leaders like <strong>Beacon Payments</strong> to reduce processing overhead and fortify transaction security for growing enterprises.</p>
    </div>

    <div class="solution-card">
        <h2>VMS Lifecycle Management</h2>
        <p>Advanced Video Management System integration. We synchronize complex security hardware with modern protocols to ensure operational continuity and data integrity.</p>
    </div>

    <div class="solution-card" style="border-left: 4px solid #a855f7;">
        <h2 style="color: #a855f7;">Proprietary AI Integration (R&D)</h2>
        <p>We are currently developing a plug-and-play AI model designed to provide proactive behavioral analytics for legacy camera systems—transforming passive monitoring into active intelligence.</p>
    </div>

    <div class="cta-section">
        <h3>Ready to optimize your infrastructure?</h3>
        <p>Schedule a technical audit or project consultation today.</p>
        <br>
        <a href="/contact" class="btn-primary">INITIATE INQUIRY</a>
    </div>
</div>
"""

with open("index.md", "w", encoding="utf-8") as f:
    f.write(homepage)

# Overwriting contact.md
contact_page = """---
layout: page
title: Inquiry Portal
---

<div style="max-width: 600px; margin: 0 auto; padding: 40px; background: #12151e; border-radius: 16px; border: 1px solid #1e293b; text-align: center;">
    <h2 style="color: #007bff;">Technical Consultation</h2>
    <p>Please use the secure portal below to schedule a time for an infrastructure audit or merchant services review.</p>
    
    <br><br>
    
    <a href="https://calendly.com/automated-technical-insights/new-meeting" 
       style="background: #007bff; color: white; padding: 18px 40px; border-radius: 8px; font-weight: bold; text-decoration: none; display: inline-block;">
       Open Secure Calendly Portal
    </a>
    
    <br><br><br>
    
    <p style="font-size: 0.9rem; color: #94a3b8;">Corporate Connectivity:<br>
    <a href="https://www.linkedin.com/in/orlando-velazquez-713bb33b7/" style="color: #007bff;">Official LinkedIn Profile</a></p>
</div>
"""

with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_page)

print("✅ Site content restructured for business legitimacy.")
# Out:
# ✅ Site content restructured for business legitimacy.

# %%
import os
if not os.path.exists('assets/css'): os.makedirs('assets/css')

refined_css = """
/* Corporate Deep Navy Theme */
:root {
    --bg-navy: #0a192f;
    --bg-card: #112240;
    --accent-blue: #007bff;
    --accent-glow: rgba(0, 123, 255, 0.6);
    --text-bright: #e6f1ff;
    --text-dim: #8892b0;
    --white: #ffffff;
}

body {
    background-color: var(--bg-navy) !important;
    color: var(--text-bright) !important;
    font-family: 'Inter', -apple-system, sans-serif;
}

/* Fix for the hard-to-read dark text */
p, li, span, h1, h2, h3 {
    color: var(--text-bright) !important;
}

/* Modern Button with Hover Shadow */
.btn-modern {
    background-color: var(--accent-blue);
    color: var(--white) !important;
    padding: 14px 28px;
    border-radius: 8px;
    text-decoration: none;
    font-weight: 700;
    display: inline-flex;
    align-items: center;
    transition: all 0.3s ease;
    border: none;
    box-shadow: 0 4px 6px rgba(0,0,0,0.3);
}

.btn-modern:hover {
    transform: translateY(-3px);
    box-shadow: 0 10px 20px var(--accent-glow);
    background-color: #0056b3;
}

/* Solution Card Styling */
.solution-card {
    background: var(--bg-card);
    border: 1px solid #233554;
    padding: 30px;
    border-radius: 12px;
    margin-bottom: 20px;
}

/* Remove the default GitHub header button */
.btn.github-button { display: none !important; }
"""

with open("assets/css/style.scss", "w", encoding="utf-8") as f:
    f.write("---\n---\n@import 'jekyll-theme-midnight';\n" + refined_css)

print("✅ High-contrast Deep Navy CSS deployed.")
# Out:
# ✅ High-contrast Deep Navy CSS deployed.

# %%
index_content = """---
layout: default
title: ATI & AI
---

<div style="padding: 40px 0; border-bottom: 1px solid #233554; margin-bottom: 40px;">
    <h1 style="color: #007bff !important; font-size: 3rem; margin: 0;">ATI & AI</h1>
    <p style="color: #8892b0 !important; font-size: 1.2rem;">Automated Technical Insights & Artificial Intelligence</p>
</div>

<div class="solution-card">
    <h2 style="color: #007bff !important;">Merchant POS Optimization</h2>
    <p>Strategic merchant services auditing and POS system integration. We partner with <strong>Beacon Payments</strong> to reduce processing overhead and fortify transaction security.</p>
</div>

<div class="solution-card">
    <h2 style="color: #007bff !important;">VMS Lifecycle Management</h2>
    <p>Advanced Video Management System integration. We synchronize complex security hardware with modern protocols to ensure operational continuity.</p>
</div>

<div class="solution-card" style="border-left: 4px solid #a855f7;">
    <h2 style="color: #a855f7 !important;">Proprietary AI Integration (R&D)</h2>
    <p>Developing a plug-and-play AI model designed to provide proactive behavioral analytics for legacy camera systems.</p>
</div>
"""

with open("index.md", "w", encoding="utf-8") as f:
    f.write(index_content)

# %%
contact_content = """---
layout: page
title: Inquiry Portal
---

<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css">

<div style="max-width: 650px; margin: 0 auto; padding: 50px; background: #112240; border-radius: 20px; border: 1px solid #233554; text-align: center;">
    <h2 style="color: #007bff !important;">Technical Consultation</h2>
    <p style="font-size: 1.1rem; line-height: 1.8;">Please use the secure portal below to schedule a time for an infrastructure audit or merchant services review.</p>
    
    <br>
    
    <a href="https://calendly.com/automated-technical-insights/new-meeting" class="btn-modern">
        <i class="fa-solid fa-calendar-check" style="margin-right: 10px;"></i> Open Secure Calendly Portal
    </a>
    
    <br><br><br>
    
    <a href="https://www.linkedin.com/in/orlando-velazquez-713bb33b7/" class="btn-modern" style="background-color: #0077b5;">
        <i class="fa-brands fa-linkedin" style="margin-right: 10px;"></i> Professional LinkedIn
    </a>

    <br><br><br>
    <hr style="border: 0; border-top: 1px solid #233554;">
    <p style="font-size: 0.8rem; color: #8892b0 !important;">Developer Resources:</p>
    <a href="https://github.com/AutomatedTechnicalInsightsandAI/AutomatedTechnicalInsightsandAI.github.io" style="color: #007bff; text-decoration: none; font-size: 0.8rem;">View Project on GitHub</a>
</div>
"""

with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_content)

print("✅ Contact Portal with LinkedIn branding finalized.")
# Out:
# ✅ Contact Portal with LinkedIn branding finalized.

# %%
# 1. Update Config to a "Clean Slate"
config_content = """
title: ATI & AI
description: Advanced Technical Insights & Artificial Intelligence
# We keep the theme for backend tools but will override the layout
remote_theme: pages-themes/midnight@v0.2.0
# This empty layout setting helps remove default theme headers
layout: null 
"""
with open("_config.yml", "w", encoding="utf-8") as f:
    f.write(config_content)

# 2. Update CSS to be even more aggressive with the Navy/Blue theme
custom_css = """
/* Force Navy Background & Bright Text */
body {
    background-color: #0a192f !important;
    color: #e6f1ff !important;
    margin: 0;
    padding: 0;
}

/* Kill the default theme's "View on GitHub" and Header */
header, .github-button, #downloads {
    display: none !important;
    visibility: hidden !important;
}

/* Create our own Premium Blue Header */
.custom-header {
    background: linear-gradient(135deg, #0f172a 0%, #1e293b 100%);
    border-bottom: 3px solid #007bff;
    padding: 60px 20px;
    text-align: center;
}

.custom-header h1 {
    color: #007bff !important;
    font-size: 3.5rem !important;
    margin: 0;
}

.custom-header p {
    color: #8892b0 !important;
    font-size: 1.3rem;
}
"""

with open("assets/css/style.scss", "w", encoding="utf-8") as f:
    f.write("---\n---\n@import 'jekyll-theme-midnight';\n" + custom_css)

print("✅ Theme defaults suppressed. Custom Navy Header active.")
# Out:
# ✅ Theme defaults suppressed. Custom Navy Header active.

# %%
homepage = """---
layout: default
---

<div class="custom-header">
    <h1>ATI & AI</h1>
    <p>Advanced Infrastructure & Strategic Intelligence</p>
</div>

<div style="max-width: 900px; margin: 40px auto; padding: 0 20px;">
    <div style="background: #112240; border: 1px solid #233554; padding: 30px; border-radius: 12px; margin-bottom: 25px;">
        <h2 style="color: #007bff !important;">Merchant POS Optimization</h2>
        <p>Strategic merchant services auditing and POS system integration. We partner with <strong>Beacon Payments</strong> to fortify transaction security.</p>
    </div>

    <div style="background: #112240; border: 1px solid #233554; padding: 30px; border-radius: 12px; margin-bottom: 25px;">
        <h2 style="color: #007bff !important;">VMS Lifecycle Management</h2>
        <p>Advanced Video Management System integration. We synchronize complex security hardware with modern protocols to ensure operational continuity.</p>
    </div>

    <div style="background: #112240; border: 1px solid #a855f7; padding: 30px; border-radius: 12px;">
        <h2 style="color: #a855f7 !important;">Proprietary AI Integration (R&D)</h2>
        <p>Transforming passive monitoring into proactive security networks via deep-learning computer vision models.</p>
    </div>
</div>
"""

with open("index.md", "w", encoding="utf-8") as f:
    f.write(homepage)

# %%
# 1. Reset Config to standard Midnight Theme
config_content = """
title: ATI & AI
description: Advanced Infrastructure & Strategic Intelligence
remote_theme: pages-themes/midnight@v0.2.0
"""
with open("_config.yml", "w", encoding="utf-8") as f:
    f.write(config_content)

# 2. Refined CSS for Readability & Icon Support
custom_css = """
/* Fix Readability for Midnight Theme */
body {
    color: #e6f1ff !important;
}

h1, h2, h3, p, li {
    color: #e6f1ff !important;
}

/* Relocate/Hide the default GitHub Button on Home */
.github-button {
    display: none !important;
}

/* Custom Buttons with Hover Effects */
.btn-modern {
    background-color: #007bff;
    color: #ffffff !important;
    padding: 12px 24px;
    border-radius: 6px;
    text-decoration: none;
    font-weight: bold;
    display: inline-flex;
    align-items: center;
    transition: all 0.3s ease;
}

.btn-modern:hover {
    box-shadow: 0 0 15px rgba(0, 123, 255, 0.6);
    transform: translateY(-2px);
}
"""

with open("assets/css/style.scss", "w", encoding="utf-8") as f:
    f.write("---\n---\n@import 'jekyll-theme-midnight';\n" + custom_css)

print("✅ Jekyll Midnight theme reset successfully.")
# Out:
# ✅ Jekyll Midnight theme reset successfully.

# %%
index_content = """---
layout: default
title: Home
---

## Strategic Solutions
ATI & AI bridges the gap between legacy hardware and modern intelligence.

### 💳 Merchant POS Optimization
We audit and optimize payment ecosystems through **Beacon Payments** to reduce overhead and secure transaction flow.

### 🔌 VMS Lifecycle Management
Advanced integration and synchronization for mission-critical Video Management Systems.

### 👁️ Intelligence Layer (R&D)
Developing deep-learning computer vision models to transform passive camera monitoring into active security intelligence.

---
[Contact the Portal](/contact)
"""

with open("index.md", "w", encoding="utf-8") as f:
    f.write(index_content)

# %%
contact_content = """---
layout: page
title: Inquiry Portal
---

<link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css">

### Technical Consultation
Please use the secure portal below to schedule a time for an infrastructure audit or merchant services review.

<br>

<a href="https://calendly.com/automated-technical-insights/new-meeting" class="btn-modern">
   <i class="fa-solid fa-calendar-check" style="margin-right:8px;"></i> Open Secure Calendly Portal
</a>

<br><br>

<a href="https://www.linkedin.com/in/orlando-velazquez-713bb33b7/" class="btn-modern" style="background-color: #0077b5;">
   <i class="fa-brands fa-linkedin" style="margin-right:8px;"></i> Official LinkedIn Profile
</a>

<br><br><br>
<hr>
<p style="font-size: 0.8rem;">Project maintained by ATI & AI</p>
<a href="https://github.com/AutomatedTechnicalInsightsandAI/AutomatedTechnicalInsightsandAI.github.io" style="font-size: 0.8rem; color: #007bff;">View on GitHub</a>
"""

with open("contact.md", "w", encoding="utf-8") as f:
    f.write(contact_content)

print("✅ Inquiry Portal updated.")
# Out:
# ✅ Inquiry Portal updated.
